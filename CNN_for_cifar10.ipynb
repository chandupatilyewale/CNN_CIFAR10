# %%
import torch
import torch.nn as nn
import torch.optim as optim

# %%
import torchvision
from torchvision.datasets import CIFAR10
from torch.utils.data import DataLoader
from torchvision.transforms import transforms

# %%
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5, 0.5, 0.5),(0.5, 0.5, 0.5))
])

# %%
trainset = CIFAR10(root = "./data",train = True, download = True, transform = transform)
testset = CIFAR10(root = "./data", train = False, download = True, transform = transform)
# Out:
#   2%|█▊                                                                          | 4.03M/170M [09:33<6:05:27, 7.59kB/s]

# %%
trainloader = DataLoader(trainset, batch_size = 64, shuffle = True)
testloader = DataLoader(testset, batch_size = 64)

# %% [markdown]
# ## Build a CNN

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv_layers = nn.Sequential(
            nn.con2d(3, 32, kernel_size = 3, padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),  # kernel size = 2 and stride = 2

            nn.con2d(32, 64, kernel_size = 3, padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),

            nn.con2d(64, 128, kernel_size = 3, padding = 1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
        )
        self.fc_layers = nn.Sequential(
            nn.Linear(4 * 4 * 128, 256),
            nn.ReLU(),
            nn.Linear(256, 10),
        )
    def forword(self, x):
        x = self.conv_layers(x),
        x = x.view(x.size(0),-1),  # flattening
        x = self.fc_layers(x)
        return x

# %%
Model = CNN

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.ADAM(Model.parameters)

# %% [markdown]
# # Training the CNN

# %%
epochs = 10
for epoch in range(epochs):
    epoch_training_loss = 0
    for images, labels in trainloader:
        optimizer.zero_grad()
        output = model.forward(images)
        loss = criterion(output,labels)
        loss.backward()
        optimizer.step()
        epoch_training_loss += loss.item()
    print(f"epoch = {epoch + 1}/{epochs} & loss = {epoch_training_loss / len(trainloader)}")

# %% [markdown]
# # Evaluate our CNN

# %%
correct_labels = 0
total_labels = 0
model.eval()
with torch.no_grad():
    for images, labels in testloader:
        output = model.forward(images)
        _, predicted = torch.max(output,1)
        correct_labels += (preducted == labels).sum().item()
        total_labels += labels.size(0)

    print(f"Accuracy = {correct_labels / total_labels * 100}")
